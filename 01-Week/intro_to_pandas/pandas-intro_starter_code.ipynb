# %% [markdown]
# # Intro to Pandas!  🐼 🐼 🐼 🐼

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# You can run terminal commands in Jupyter Notebook!

# %%
pwd
# Out:
# '/Users/ericschultz/GA/DC-Flex/01-Week/intro_to_pandas'

# %%
ls
# Out:
# pandas-intro_starter_code.ipynb

# %%
df_sat = pd.read_csv('../data/sat_scores.csvres.csv')

# %% [markdown]
# Read the data into a pandas DataFrame

# %%
df_sat
# Out:
#    State  Rate  Verbal  Math
# 0     CT    82     509   510
# 1     NJ    81     499   513
# 2     MA    79     511   515
# 3     NY    77     495   505
# 4     NH    72     520   516
# 5     RI    71     501   499
# 6     PA    71     500   499
# 7     VT    69     511   506
# 8     ME    69     506   500
# 9     VA    68     510   501
# 10    DE    67     501   499
# 11    MD    65     508   510
# 12    NC    65     493   499
# 13    GA    63     491   489
# 14    IN    60     499   501
# 15    SC    57     486   488
# 16    DC    56     482   474
# 17    OR    55     526   526
# 18    FL    54     498   499
# 19    WA    53     527   527
# 20    TX    53     493   499
# 21    HI    52     485   515
# 22    AK    51     514   510
# 23    CA    51     498   517
# 24    AZ    34     523   525
# 25    NV    33     509   515
# 26    CO    31     539   542
# 27    OH    26     534   439
# 28    MT    23     539   539
# 29    WV    18     527   512
# 30    ID    17     543   542
# 31    TN    13     562   553
# 32    NM    13     551   542
# 33    IL    12     576   589
# 34    KY    12     550   550
# 35    WY    11     547   545
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551
# 51   All    45     506   514

# %% [markdown]
# View the DataFrame

# %%
# Check the first five rows 
df_sat.head()
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516

# %%
# Check the last five rows 
df_sat.tail()
# Out:
#    State  Rate  Verbal  Math
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551
# 51   All    45     506   514

# %%
# number of rows of columns
df_sat.shape
# Out:
# (52, 4)

# %%
# get info 
df_sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   52 non-null     object
#  1   Rate    52 non-null     int64
#  2   Verbal  52 non-null     int64
#  3   Math    52 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.8+ KB

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
# get the index of the data frame. The index is not a column. Notice it is an attribute
df_sat.index
# Out:
# RangeIndex(start=0, stop=52, step=1)

# %%
# get a list of columns
df_sat.columns
# Out:
# Index(['State', 'Rate', 'Verbal', 'Math'], dtype='object')

# %%
# check for missing values - get the number of missing values
df_sat.isnull().sum()
# Out:
# State     0
# Rate      0
# Verbal    0
# Math      0
# dtype: int64

# %%
type(df_sat.isnull().sum())
# Out:
# pandas.core.series.Series

# %%
# check for missing values - get the percentage of missing values
df_sat.isnull()
# Out:
# State     0.0
# Rate      0.0
# Verbal    0.0
# Math      0.0
# dtype: float64

# %%
# Get unique observation
df_sat.nunique()
# Out:
# State     52
# Rate      36
# Verbal    39
# Math      38
# dtype: int64

# %%
# get summary statistics
df_sat.describe(include='all')
# Out:
#        State       Rate      Verbal        Math
# count     52  52.000000   52.000000   52.000000
# unique    52        NaN         NaN         NaN
# top       VA        NaN         NaN         NaN
# freq       1        NaN         NaN         NaN
# mean     NaN  37.153846  532.019231  531.500000
# std      NaN  27.301788   33.236225   36.014975
# min      NaN   4.000000  482.000000  439.000000
# 25%      NaN   9.000000  501.000000  504.000000
# 50%      NaN  33.500000  526.500000  521.000000
# 75%      NaN  63.500000  562.000000  555.750000
# max      NaN  82.000000  593.000000  603.000000

# %%
# Standard Deviation
df_sat.std()
# Out:
# Rate      27.301788
# Verbal    33.236225
# Math      36.014975
# dtype: float64

# %% [markdown]
# ### 5 ways to select columns

# %%
# Dot notation. I highly suggest you don't use this!
df_sat.columns

# %%
# Using square brackets - returns a data series
df_sat['State']
# Out:
# 0      CT
# 1      NJ
# 2      MA
# 3      NY
# 4      NH
# 5      RI
# 6      PA
# 7      VT
# 8      ME
# 9      VA
# 10     DE
# 11     MD
# 12     NC
# 13     GA
# 14     IN
# 15     SC
# 16     DC
# 17     OR
# 18     FL
# 19     WA
# 20     TX
# 21     HI
# 22     AK
# 23     CA
# 24     AZ
# 25     NV
# 26     CO
# 27     OH
# 28     MT
# 29     WV
# 30     ID
# 31     TN
# 32     NM
# 33     IL
# 34     KY
# 35     WY
# 36     MI
# 37     MN
# 38     KS
# 39     AL
# 40     NE
# 41     OK
# 42     MO
# 43     LA
# 44     WI
# 45     AR
# 46     UT
# 47     IA
# 48     SD
# 49     ND
# 50     MS
# 51    All
# Name: State, dtype: object

# %%
# Using doube square brackets - returns a data frame
df_sat[['State']]
# Out:
#    State
# 0     CT
# 1     NJ
# 2     MA
# 3     NY
# 4     NH
# 5     RI
# 6     PA
# 7     VT
# 8     ME
# 9     VA
# 10    DE
# 11    MD
# 12    NC
# 13    GA
# 14    IN
# 15    SC
# 16    DC
# 17    OR
# 18    FL
# 19    WA
# 20    TX
# 21    HI
# 22    AK
# 23    CA
# 24    AZ
# 25    NV
# 26    CO
# 27    OH
# 28    MT
# 29    WV
# 30    ID
# 31    TN
# 32    NM
# 33    IL
# 34    KY
# 35    WY
# 36    MI
# 37    MN
# 38    KS
# 39    AL
# 40    NE
# 41    OK
# 42    MO
# 43    LA
# 44    WI
# 45    AR
# 46    UT
# 47    IA
# 48    SD
# 49    ND
# 50    MS
# 51   All

# %%
type(df_sat[['State']]) # the dub brackets are a dataframe--yay!
# Out:
# pandas.core.frame.DataFrame

# %%
# Using .loc to select columns, name based
df_sat.loc[:,['Math']] # using just ':' gives ALL rows
# Out:
#     Math
# 0    510
# 1    513
# 2    515
# 3    505
# 4    516
# 5    499
# 6    499
# 7    506
# 8    500
# 9    501
# 10   499
# 11   510
# 12   499
# 13   489
# 14   501
# 15   488
# 16   474
# 17   526
# 18   499
# 19   527
# 20   499
# 21   515
# 22   510
# 23   517
# 24   525
# 25   515
# 26   542
# 27   439
# 28   539
# 29   512
# 30   542
# 31   553
# 32   542
# 33   589
# 34   550
# 35   545
# 36   572
# 37   589
# 38   580
# 39   554
# 40   568
# 41   561
# 42   577
# 43   562
# 44   596
# 45   550
# 46   570
# 47   603
# 48   582
# 49   599
# 50   551
# 51   514

# %%
df_sat.loc[0:10, ['Math','Verbal']] # I can slice rows using the ':'
# Out:
#     Math  Verbal
# 0    510     509
# 1    513     499
# 2    515     511
# 3    505     495
# 4    516     520
# 5    499     501
# 6    499     500
# 7    506     511
# 8    500     506
# 9    501     510
# 10   499     501

# %%
df_sat.loc[0:10, ['Math']] # 1 column returns a series
# Out:
#     Math
# 0    510
# 1    513
# 2    515
# 3    505
# 4    516
# 5    499
# 6    499
# 7    506
# 8    500
# 9    501
# 10   499

# %%
df_sat.loc[0:10, ['Math','Verbal']] # two columns retun a data frame!
# Out:
#     Math  Verbal
# 0    510     509
# 1    513     499
# 2    515     511
# 3    505     495
# 4    516     520
# 5    499     501
# 6    499     500
# 7    506     511
# 8    500     506
# 9    501     510
# 10   499     501

# %%
# Use iloc, number based
df_sat.iloc[0:10]
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516
# 5    RI    71     501   499
# 6    PA    71     500   499
# 7    VT    69     511   506
# 8    ME    69     506   500
# 9    VA    68     510   501

# %%
# Single VS Double brackets
#double = dartaframe, single = series

# %%
# Value counts of variabe
df_sat['Math'].value_counts(normalize=True)
# Out:
# 499    0.115385
# 510    0.057692
# 515    0.057692
# 542    0.057692
# 550    0.038462
# 501    0.038462
# 589    0.038462
# 527    0.019231
# 474    0.019231
# 599    0.019231
# 596    0.019231
# 514    0.019231
# 570    0.019231
# 525    0.019231
# 526    0.019231
# 582    0.019231
# 517    0.019231
# 516    0.019231
# 577    0.019231
# 513    0.019231
# 539    0.019231
# 551    0.019231
# 545    0.019231
# 572    0.019231
# 603    0.019231
# 488    0.019231
# 489    0.019231
# 554    0.019231
# 580    0.019231
# 561    0.019231
# 562    0.019231
# 500    0.019231
# 553    0.019231
# 439    0.019231
# 568    0.019231
# 505    0.019231
# 506    0.019231
# 512    0.019231
# Name: Math, dtype: float64

# %%
# Unique values
df_sat['Math'].unique()
# Out:
# array([510, 513, 515, 505, 516, 499, 506, 500, 501, 489, 488, 474, 526,
#        527, 517, 525, 542, 439, 539, 512, 553, 589, 550, 545, 572, 580,
#        554, 568, 561, 577, 562, 596, 570, 603, 582, 599, 551, 514])

# %%
df_sat.shape
# Out:
# (52, 4)

# %%
# Number of unique values
sat['Math'].nunique()

# %%
# Summary statistics of one columns
df_sat['Math'].describe()
# Out:
# count     52.000000
# mean     531.500000
# std       36.014975
# min      439.000000
# 25%      504.000000
# 50%      521.000000
# 75%      555.750000
# max      603.000000
# Name: Math, dtype: float64

# %%
# Average of the column
df_sat['Math'].mean()
# Out:
# 531.5

# %%
# Selecting multiple columns
df_sat[['Math', 'Verbal']]
# Out:
#     Math  Verbal
# 0    510     509
# 1    513     499
# 2    515     511
# 3    505     495
# 4    516     520
# 5    499     501
# 6    499     500
# 7    506     511
# 8    500     506
# 9    501     510
# 10   499     501
# 11   510     508
# 12   499     493
# 13   489     491
# 14   501     499
# 15   488     486
# 16   474     482
# 17   526     526
# 18   499     498
# 19   527     527
# 20   499     493
# 21   515     485
# 22   510     514
# 23   517     498
# 24   525     523
# 25   515     509
# 26   542     539
# 27   439     534
# 28   539     539
# 29   512     527
# 30   542     543
# 31   553     562
# 32   542     551
# 33   589     576
# 34   550     550
# 35   545     547
# 36   572     561
# 37   589     580
# 38   580     577
# 39   554     559
# 40   568     562
# 41   561     567
# 42   577     577
# 43   562     564
# 44   596     584
# 45   550     562
# 46   570     575
# 47   603     593
# 48   582     577
# 49   599     592
# 50   551     566
# 51   514     506

# %%
# .loc method

# %%
df_sat.loc[:,['Math','Verbal']]
# Out:
#     Math  Verbal
# 0    510     509
# 1    513     499
# 2    515     511
# 3    505     495
# 4    516     520
# 5    499     501
# 6    499     500
# 7    506     511
# 8    500     506
# 9    501     510
# 10   499     501
# 11   510     508
# 12   499     493
# 13   489     491
# 14   501     499
# 15   488     486
# 16   474     482
# 17   526     526
# 18   499     498
# 19   527     527
# 20   499     493
# 21   515     485
# 22   510     514
# 23   517     498
# 24   525     523
# 25   515     509
# 26   542     539
# 27   439     534
# 28   539     539
# 29   512     527
# 30   542     543
# 31   553     562
# 32   542     551
# 33   589     576
# 34   550     550
# 35   545     547
# 36   572     561
# 37   589     580
# 38   580     577
# 39   554     559
# 40   568     562
# 41   561     567
# 42   577     577
# 43   562     564
# 44   596     584
# 45   550     562
# 46   570     575
# 47   603     593
# 48   582     577
# 49   599     592
# 50   551     566
# 51   514     506

# %% [markdown]
# # Filtering

# %%
# Get states where math grade is higher than 550(using a mask variable)
df_sat['Math'] > 550
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31     True
# 32    False
# 33     True
# 34    False
# 35    False
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45    False
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51    False
# Name: Math, dtype: bool

# %%
mask = df_sat['Math'] > 550

# %%
df_sat[mask]
# Out:
#    State  Rate  Verbal  Math
# 31    TN    13     562   553
# 33    IL    12     576   589
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %%
# using a mask, without defining a variable
df_sat[df_sat['Math'] > 550]
# Out:
#    State  Rate  Verbal  Math
# 31    TN    13     562   553
# 33    IL    12     576   589
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %%
# Get the states with higher than average math grade
df_sat[df_sat['Math'] > df_sat['Math'].mean()]
# Out:
#    State  Rate  Verbal  Math
# 26    CO    31     539   542
# 28    MT    23     539   539
# 30    ID    17     543   542
# 31    TN    13     562   553
# 32    NM    13     551   542
# 33    IL    12     576   589
# 34    KY    12     550   550
# 35    WY    11     547   545
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %%
# Get the states with higher than median math grade
df_sat[df_sat['Math'] > df_sat['Math'].median()]
# Out:
#    State  Rate  Verbal  Math
# 17    OR    55     526   526
# 19    WA    53     527   527
# 24    AZ    34     523   525
# 26    CO    31     539   542
# 28    MT    23     539   539
# 30    ID    17     543   542
# 31    TN    13     562   553
# 32    NM    13     551   542
# 33    IL    12     576   589
# 34    KY    12     550   550
# 35    WY    11     547   545
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %% [markdown]
# ## Sorting

# %%
# Ascending
df_sat.sort_values(by='Math')
# Out:
#    State  Rate  Verbal  Math
# 27    OH    26     534   439
# 16    DC    56     482   474
# 15    SC    57     486   488
# 13    GA    63     491   489
# 20    TX    53     493   499
# 5     RI    71     501   499
# 6     PA    71     500   499
# 18    FL    54     498   499
# 10    DE    67     501   499
# 12    NC    65     493   499
# 8     ME    69     506   500
# 14    IN    60     499   501
# 9     VA    68     510   501
# 3     NY    77     495   505
# 7     VT    69     511   506
# 22    AK    51     514   510
# 11    MD    65     508   510
# 0     CT    82     509   510
# 29    WV    18     527   512
# 1     NJ    81     499   513
# 51   All    45     506   514
# 21    HI    52     485   515
# 2     MA    79     511   515
# 25    NV    33     509   515
# 4     NH    72     520   516
# 23    CA    51     498   517
# 24    AZ    34     523   525
# 17    OR    55     526   526
# 19    WA    53     527   527
# 28    MT    23     539   539
# 26    CO    31     539   542
# 30    ID    17     543   542
# 32    NM    13     551   542
# 35    WY    11     547   545
# 34    KY    12     550   550
# 45    AR     6     562   550
# 50    MS     4     566   551
# 31    TN    13     562   553
# 39    AL     9     559   554
# 41    OK     8     567   561
# 43    LA     7     564   562
# 40    NE     8     562   568
# 46    UT     5     575   570
# 36    MI    11     561   572
# 42    MO     8     577   577
# 38    KS     9     577   580
# 48    SD     4     577   582
# 33    IL    12     576   589
# 37    MN     9     580   589
# 44    WI     6     584   596
# 49    ND     4     592   599
# 47    IA     5     593   603

# %%
# Decsending
df_sat.sort_values(by=['Math', 'Verbal'], ascending = False)
# Out:
#    State  Rate  Verbal  Math
# 47    IA     5     593   603
# 49    ND     4     592   599
# 44    WI     6     584   596
# 37    MN     9     580   589
# 33    IL    12     576   589
# 48    SD     4     577   582
# 38    KS     9     577   580
# 42    MO     8     577   577
# 36    MI    11     561   572
# 46    UT     5     575   570
# 40    NE     8     562   568
# 43    LA     7     564   562
# 41    OK     8     567   561
# 39    AL     9     559   554
# 31    TN    13     562   553
# 50    MS     4     566   551
# 45    AR     6     562   550
# 34    KY    12     550   550
# 35    WY    11     547   545
# 32    NM    13     551   542
# 30    ID    17     543   542
# 26    CO    31     539   542
# 28    MT    23     539   539
# 19    WA    53     527   527
# 17    OR    55     526   526
# 24    AZ    34     523   525
# 23    CA    51     498   517
# 4     NH    72     520   516
# 2     MA    79     511   515
# 25    NV    33     509   515
# 21    HI    52     485   515
# 51   All    45     506   514
# 1     NJ    81     499   513
# 29    WV    18     527   512
# 22    AK    51     514   510
# 0     CT    82     509   510
# 11    MD    65     508   510
# 7     VT    69     511   506
# 3     NY    77     495   505
# 9     VA    68     510   501
# 14    IN    60     499   501
# 8     ME    69     506   500
# 5     RI    71     501   499
# 10    DE    67     501   499
# 6     PA    71     500   499
# 18    FL    54     498   499
# 12    NC    65     493   499
# 20    TX    53     493   499
# 13    GA    63     491   489
# 15    SC    57     486   488
# 16    DC    56     482   474
# 27    OH    26     534   439

# %%
df_sat['Math'].max()
# Out:
# 603

# %% [markdown]
# ## Plotting

# %%
# Plot a histogram of Math grades - one way
df_sat['Math'].plot(kind='hist');

# %%
# Plot a histogram of Math grades - another way
df_sat['Math'].hist();

# %%
# Scatter plot - relationship between two variables
df_sat.plot(x='Math', y='Verbal', kind = 'scatter')

# %%
# Correlation matrix
df_sat.corr()
# Out:
#             Rate    Verbal      Math
# Rate    1.000000 -0.886432 -0.773746
# Verbal -0.886432  1.000000  0.899871
# Math   -0.773746  0.899871  1.000000

# %% [markdown]
# # Pandas rocks!!!!! 🐼 🐼 🐼 🐼 🐼
