# %% [markdown]
# # Intro to Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# You can run terminal commands in Jupyter Notebook!

# %%
pwd
# Out:
# '/Users/adibronshtein/Documents/General-Assembly/DSI/DC-Flex/01-Week'

# %%
ls
# Out:
# 01-Jupyter-Notebooks-and-Data-Types-Review-Adi.ipynb
# 01-Jupyter-Notebooks-and-Data-Types-Review.ipynb
# 02-python-controlflow.ipynb
# 03-python-functions-in-class-adi.ipynb*
# 03-python-functions.ipynb
# 04-functions_overview.ipynb*
# 05-quiz_1_review-Adi-in-class.ipynb
# 05-quiz_1_review.ipynb*
# 06-Pandas-intro.pdf*
# 06-pandas-intro-Adi.ipynb
# Readme.md
# assets/
# data/

# %%
ls
# Out:
# 01-Jupyter-Notebooks-and-Data-Types-Review-Adi.ipynb
# 01-Jupyter-Notebooks-and-Data-Types-Review.ipynb
# 02-python-controlflow.ipynb
# 03-python-functions-in-class-adi.ipynb*
# 03-python-functions.ipynb
# 04-functions_overview.ipynb*
# 05-quiz_1_review-Adi-in-class.ipynb
# 05-quiz_1_review.ipynb*
# 06-Pandas-intro.pdf*
# 06-pandas-intro-Adi.ipynb
# Readme.md
# assets/
# data/

# %%
sat = pd.read_csv('./data/sat_scores.csv')

# %%
type(sat)
# Out:
# pandas.core.frame.DataFrame

# %%
# Check the first five rows 
sat.head()
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516
# 5    RI    71     501   499
# 6    PA    71     500   499
# 7    VT    69     511   506
# 8    ME    69     506   500
# 9    VA    68     510   501

# %%
# Check the last five rows 
sat.tail()
# Out:
#    State  Rate  Verbal  Math
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551
# 51   All    45     506   514

# %%
# number of rows of columns
sat.shape
# Out:
# (52, 4)

# %%
# get info 
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
# State     52 non-null object
# Rate      52 non-null int64
# Verbal    52 non-null int64
# Math      52 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 1.8+ KB

# %%
# get the index of the data frame
sat.index
# Out:
# RangeIndex(start=0, stop=52, step=1)

# %%
# check for missing values - get the number of missing values
sat.isnull().sum()
# Out:
# State     0
# Rate      0
# Verbal    0
# Math      0
# dtype: int64

# %%
# check for missing values - get the percentage of missing values
sat.isnull().mean()
# Out:
# State     0.0
# Rate      0.0
# Verbal    0.0
# Math      0.0
# dtype: float64

# %%
# Get unique observation
sat.nunique()
# Out:
# State     52
# Rate      36
# Verbal    39
# Math      38
# dtype: int64

# %%
# get summary statistics
sat.describe()
# Out:
#             Rate      Verbal        Math
# count  52.000000   52.000000   52.000000
# mean   37.153846  532.019231  531.500000
# std    27.301788   33.236225   36.014975
# min     4.000000  482.000000  439.000000
# 25%     9.000000  501.000000  504.000000
# 50%    33.500000  526.500000  521.000000
# 75%    63.500000  562.000000  555.750000
# max    82.000000  593.000000  603.000000

# %%
# Standard Deviation
sat.std()
# Out:
# Rate      27.301788
# Verbal    33.236225
# Math      36.014975
# dtype: float64

# %%
# get a list of columns
sat.columns
# Out:
# Index(['State', 'Rate', 'Verbal', 'Math'], dtype='object')

# %% [markdown]
# ### 3 ways to select columns

# %%
# Dot notation
sat.State
# Out:
# 0      CT
# 1      NJ
# 2      MA
# 3      NY
# 4      NH
# 5      RI
# 6      PA
# 7      VT
# 8      ME
# 9      VA
# 10     DE
# 11     MD
# 12     NC
# 13     GA
# 14     IN
# 15     SC
# 16     DC
# 17     OR
# 18     FL
# 19     WA
# 20     TX
# 21     HI
# 22     AK
# 23     CA
# 24     AZ
# 25     NV
# 26     CO
# 27     OH
# 28     MT
# 29     WV
# 30     ID
# 31     TN
# 32     NM
# 33     IL
# 34     KY
# 35     WY
# 36     MI
# 37     MN
# 38     KS
# 39     AL
# 40     NE
# 41     OK
# 42     MO
# 43     LA
# 44     WI
# 45     AR
# 46     UT
# 47     IA
# 48     SD
# 49     ND
# 50     MS
# 51    All
# Name: State, dtype: object

# %%
# Using square brackets - returns a data series
sat['State']
# Out:
# 0      CT
# 1      NJ
# 2      MA
# 3      NY
# 4      NH
# 5      RI
# 6      PA
# 7      VT
# 8      ME
# 9      VA
# 10     DE
# 11     MD
# 12     NC
# 13     GA
# 14     IN
# 15     SC
# 16     DC
# 17     OR
# 18     FL
# 19     WA
# 20     TX
# 21     HI
# 22     AK
# 23     CA
# 24     AZ
# 25     NV
# 26     CO
# 27     OH
# 28     MT
# 29     WV
# 30     ID
# 31     TN
# 32     NM
# 33     IL
# 34     KY
# 35     WY
# 36     MI
# 37     MN
# 38     KS
# 39     AL
# 40     NE
# 41     OK
# 42     MO
# 43     LA
# 44     WI
# 45     AR
# 46     UT
# 47     IA
# 48     SD
# 49     ND
# 50     MS
# 51    All
# Name: State, dtype: object

# %%
# Using doube square brackets - returns a data frame
sat[['State']]
# Out:
#    State
# 0     CT
# 1     NJ
# 2     MA
# 3     NY
# 4     NH
# 5     RI
# 6     PA
# 7     VT
# 8     ME
# 9     VA
# 10    DE
# 11    MD
# 12    NC
# 13    GA
# 14    IN
# 15    SC
# 16    DC
# 17    OR
# 18    FL
# 19    WA
# 20    TX
# 21    HI
# 22    AK
# 23    CA
# 24    AZ
# 25    NV
# 26    CO
# 27    OH
# 28    MT
# 29    WV
# 30    ID
# 31    TN
# 32    NM
# 33    IL
# 34    KY
# 35    WY
# 36    MI
# 37    MN
# 38    KS
# 39    AL
# 40    NE
# 41    OK
# 42    MO
# 43    LA
# 44    WI
# 45    AR
# 46    UT
# 47    IA
# 48    SD
# 49    ND
# 50    MS
# 51   All

# %%
# Using .loc to select columns
sat.loc[:, 'Math'] # using just ':' gives ALL rows

# %%
sat.loc[0:10, ['Math','Verbal']] # I can slice rows using the ':'
# Out:
#     Math  Verbal
# 0    510     509
# 1    513     499
# 2    515     511
# 3    505     495
# 4    516     520
# 5    499     501
# 6    499     500
# 7    506     511
# 8    500     506
# 9    501     510
# 10   499     501

# %%
sat.loc[0:10, ['Math']] # 1 column returns a series
# Out:
#     Math
# 0    510
# 1    513
# 2    515
# 3    505
# 4    516
# 5    499
# 6    499
# 7    506
# 8    500
# 9    501
# 10   499

# %%
sat.loc[0:10, ['Math','Verbal']] # two columns retun a data frame!
# Out:
#     Math  Verbal
# 0    510     509
# 1    513     499
# 2    515     511
# 3    505     495
# 4    516     520
# 5    499     501
# 6    499     500
# 7    506     511
# 8    500     506
# 9    501     510
# 10   499     501

# %%
# Use iloc
sat.iloc[0:10]
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516
# 5    RI    71     501   499
# 6    PA    71     500   499
# 7    VT    69     511   506
# 8    ME    69     506   500
# 9    VA    68     510   501

# %%
# Single VS Double brackets
print(type(sat['State']))
print(type(sat[['State']]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# Value counts of variabe
sat['State'].value_counts()
# Out:
# RI     1
# DE     1
# NY     1
# CA     1
# LA     1
# FL     1
# OR     1
# IL     1
# SC     1
# GA     1
# VT     1
# AR     1
# NC     1
# NE     1
# MO     1
# SD     1
# DC     1
# UT     1
# WA     1
# All    1
# TN     1
# HI     1
# AL     1
# WV     1
# KS     1
# KY     1
# NH     1
# ID     1
# IA     1
# NM     1
# MT     1
# AZ     1
# MA     1
# NV     1
# ND     1
# OK     1
# WI     1
# OH     1
# MS     1
# VA     1
# MI     1
# IN     1
# CT     1
# MD     1
# AK     1
# CO     1
# WY     1
# TX     1
# NJ     1
# PA     1
# ME     1
# MN     1
# Name: State, dtype: int64

# %%
sat['Math'].value_counts()
# Out:
# 499    6
# 510    3
# 515    3
# 542    3
# 550    2
# 501    2
# 589    2
# 527    1
# 474    1
# 599    1
# 596    1
# 514    1
# 570    1
# 525    1
# 526    1
# 582    1
# 517    1
# 516    1
# 577    1
# 513    1
# 539    1
# 551    1
# 545    1
# 572    1
# 603    1
# 488    1
# 489    1
# 554    1
# 580    1
# 561    1
# 562    1
# 500    1
# 553    1
# 439    1
# 568    1
# 505    1
# 506    1
# 512    1
# Name: Math, dtype: int64

# %%
# Unique values
sat['Math'].uniquee()
# Out:
# array([510, 513, 515, 505, 516, 499, 506, 500, 501, 489, 488, 474, 526,
#        527, 517, 525, 542, 439, 539, 512, 553, 589, 550, 545, 572, 580,
#        554, 568, 561, 577, 562, 596, 570, 603, 582, 599, 551, 514])

# %%
# Number of unique values
sat['Math'].nunique()
# Out:
# 38

# %%
# Summary statistics of one columns
sat['Verbal'].describe()
# Out:
# count     52.000000
# mean     532.019231
# std       33.236225
# min      482.000000
# 25%      501.000000
# 50%      526.500000
# 75%      562.000000
# max      593.000000
# Name: Verbal, dtype: float64

# %%
# Average of the column
sat['Verbal'].mean()
# Out:
# 532.0192307692307

# %%
# Selecting multiple columns
sat[['Verbal','Math']]
# Out:
#     Verbal  Math
# 0      509   510
# 1      499   513
# 2      511   515
# 3      495   505
# 4      520   516
# 5      501   499
# 6      500   499
# 7      511   506
# 8      506   500
# 9      510   501
# 10     501   499
# 11     508   510
# 12     493   499
# 13     491   489
# 14     499   501
# 15     486   488
# 16     482   474
# 17     526   526
# 18     498   499
# 19     527   527
# 20     493   499
# 21     485   515
# 22     514   510
# 23     498   517
# 24     523   525
# 25     509   515
# 26     539   542
# 27     534   439
# 28     539   539
# 29     527   512
# 30     543   542
# 31     562   553
# 32     551   542
# 33     576   589
# 34     550   550
# 35     547   545
# 36     561   572
# 37     580   589
# 38     577   580
# 39     559   554
# 40     562   568
# 41     567   561
# 42     577   577
# 43     564   562
# 44     584   596
# 45     562   550
# 46     575   570
# 47     593   603
# 48     577   582
# 49     592   599
# 50     566   551
# 51     506   514

# %% [markdown]
# # Filtering

# %%
# Get states where math grade is higher than 550(using a mask variable)
mask = sat['Math'] > 550
sat[mask]
# Out:
#    State  Rate  Verbal  Math
# 31    TN    13     562   553
# 33    IL    12     576   589
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %%
# using a mask, without defining a variable
sat[sat['Math'] > 550]
# Out:
#    State  Rate  Verbal  Math
# 31    TN    13     562   553
# 33    IL    12     576   589
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %%
# Get the states with higher than average math grade
sat[sat['Math'] > sat['Math'].mean()]
# Out:
#    State  Rate  Verbal  Math
# 26    CO    31     539   542
# 28    MT    23     539   539
# 30    ID    17     543   542
# 31    TN    13     562   553
# 32    NM    13     551   542
# 33    IL    12     576   589
# 34    KY    12     550   550
# 35    WY    11     547   545
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %%
# Get the states with higher than median math grade
sat[sat['Math'] > sat['Math'].median()]
# Out:
#    State  Rate  Verbal  Math
# 17    OR    55     526   526
# 19    WA    53     527   527
# 24    AZ    34     523   525
# 26    CO    31     539   542
# 28    MT    23     539   539
# 30    ID    17     543   542
# 31    TN    13     562   553
# 32    NM    13     551   542
# 33    IL    12     576   589
# 34    KY    12     550   550
# 35    WY    11     547   545
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %% [markdown]
# ## Sorting

# %%
# Ascending
sat.sort_values(by='Math')
# Out:
#    State  Rate  Verbal  Math
# 27    OH    26     534   439
# 16    DC    56     482   474
# 15    SC    57     486   488
# 13    GA    63     491   489
# 20    TX    53     493   499
# 5     RI    71     501   499
# 6     PA    71     500   499
# 18    FL    54     498   499
# 10    DE    67     501   499
# 12    NC    65     493   499
# 8     ME    69     506   500
# 14    IN    60     499   501
# 9     VA    68     510   501
# 3     NY    77     495   505
# 7     VT    69     511   506
# 22    AK    51     514   510
# 11    MD    65     508   510
# 0     CT    82     509   510
# 29    WV    18     527   512
# 1     NJ    81     499   513
# 51   All    45     506   514
# 21    HI    52     485   515
# 2     MA    79     511   515
# 25    NV    33     509   515
# 4     NH    72     520   516
# 23    CA    51     498   517
# 24    AZ    34     523   525
# 17    OR    55     526   526
# 19    WA    53     527   527
# 28    MT    23     539   539
# 26    CO    31     539   542
# 30    ID    17     543   542
# 32    NM    13     551   542
# 35    WY    11     547   545
# 34    KY    12     550   550
# 45    AR     6     562   550
# 50    MS     4     566   551
# 31    TN    13     562   553
# 39    AL     9     559   554
# 41    OK     8     567   561
# 43    LA     7     564   562
# 40    NE     8     562   568
# 46    UT     5     575   570
# 36    MI    11     561   572
# 42    MO     8     577   577
# 38    KS     9     577   580
# 48    SD     4     577   582
# 33    IL    12     576   589
# 37    MN     9     580   589
# 44    WI     6     584   596
# 49    ND     4     592   599
# 47    IA     5     593   603

# %%
# Decsending
sat.sort_values(by='Math', ascending=False)
# Out:
#    State  Rate  Verbal  Math
# 47    IA     5     593   603
# 49    ND     4     592   599
# 44    WI     6     584   596
# 37    MN     9     580   589
# 33    IL    12     576   589
# 48    SD     4     577   582
# 38    KS     9     577   580
# 42    MO     8     577   577
# 36    MI    11     561   572
# 46    UT     5     575   570
# 40    NE     8     562   568
# 43    LA     7     564   562
# 41    OK     8     567   561
# 39    AL     9     559   554
# 31    TN    13     562   553
# 50    MS     4     566   551
# 45    AR     6     562   550
# 34    KY    12     550   550
# 35    WY    11     547   545
# 32    NM    13     551   542
# 26    CO    31     539   542
# 30    ID    17     543   542
# 28    MT    23     539   539
# 19    WA    53     527   527
# 17    OR    55     526   526
# 24    AZ    34     523   525
# 23    CA    51     498   517
# 4     NH    72     520   516
# 21    HI    52     485   515
# 25    NV    33     509   515
# 2     MA    79     511   515
# 51   All    45     506   514
# 1     NJ    81     499   513
# 29    WV    18     527   512
# 11    MD    65     508   510
# 0     CT    82     509   510
# 22    AK    51     514   510
# 7     VT    69     511   506
# 3     NY    77     495   505
# 14    IN    60     499   501
# 9     VA    68     510   501
# 8     ME    69     506   500
# 20    TX    53     493   499
# 18    FL    54     498   499
# 10    DE    67     501   499
# 6     PA    71     500   499
# 5     RI    71     501   499
# 12    NC    65     493   499
# 13    GA    63     491   489
# 15    SC    57     486   488
# 16    DC    56     482   474
# 27    OH    26     534   439

# %%
sat.sort_values(by=['Math','Verbal'], ascending=False)
# Out:
#    State  Rate  Verbal  Math
# 47    IA     5     593   603
# 49    ND     4     592   599
# 44    WI     6     584   596
# 37    MN     9     580   589
# 33    IL    12     576   589
# 48    SD     4     577   582
# 38    KS     9     577   580
# 42    MO     8     577   577
# 36    MI    11     561   572
# 46    UT     5     575   570
# 40    NE     8     562   568
# 43    LA     7     564   562
# 41    OK     8     567   561
# 39    AL     9     559   554
# 31    TN    13     562   553
# 50    MS     4     566   551
# 45    AR     6     562   550
# 34    KY    12     550   550
# 35    WY    11     547   545
# 32    NM    13     551   542
# 30    ID    17     543   542
# 26    CO    31     539   542
# 28    MT    23     539   539
# 19    WA    53     527   527
# 17    OR    55     526   526
# 24    AZ    34     523   525
# 23    CA    51     498   517
# 4     NH    72     520   516
# 2     MA    79     511   515
# 25    NV    33     509   515
# 21    HI    52     485   515
# 51   All    45     506   514
# 1     NJ    81     499   513
# 29    WV    18     527   512
# 22    AK    51     514   510
# 0     CT    82     509   510
# 11    MD    65     508   510
# 7     VT    69     511   506
# 3     NY    77     495   505
# 9     VA    68     510   501
# 14    IN    60     499   501
# 8     ME    69     506   500
# 5     RI    71     501   499
# 10    DE    67     501   499
# 6     PA    71     500   499
# 18    FL    54     498   499
# 12    NC    65     493   499
# 20    TX    53     493   499
# 13    GA    63     491   489
# 15    SC    57     486   488
# 16    DC    56     482   474
# 27    OH    26     534   439

# %% [markdown]
# ## Plotting

# %%
# Plot a histogram of Math grades - one way
sat['Math'].plot(kind='hist');

# %%
# Plot a histogram of Math grades - another way
sat['Math'].hist();

# %%
# Scatter plot - relationship between two variables
sat.plot.scatter(x='Math', y='Verbal',figsize=(10,8));

# %%
# Correlation matrix
sat.corr()
# Out:
#             Rate    Verbal      Math
# Rate    1.000000 -0.886432 -0.773746
# Verbal -0.886432  1.000000  0.899871
# Math   -0.773746  0.899871  1.000000
