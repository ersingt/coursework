# %% [markdown]
# # Challenge
#
# Have fun and build your skills! 🚀

# %% [markdown]
# ### Goal
#
# Predict `ratings_simplified` using the the `review` column only. If there's time after you have a good model working and hypertuned, then you can use `drugName`, and `condition`, columns in your model too.
#
# The goal is to make a model that scores well on your 25% of the test (holdout) set, without any data leakage. Use `random_state = 123` in `train_test_split`.
#
#
# ### Roles
#
# - One person from your group will be the spokesperson who will present your results.
# - Another person is the moderator who will keep the group on task and make sure everything is humming along and everyone is on board with decisions and understands what's happening.
# - The third person will share their screen and keep the official notebook for the group (everyone should work on their own notebook, too).
#
# Everyone should have a different role than they had last time.
#
# ### Instructions
#
# Use GridSearchCV, a pipeline, and any model you like:
#
# To grid search with a pipeline:
#
# - Make a GridSearchCV object, put a pipeline with transformers and an estimator in it.
#
# - Use column transformers to apply specific transformations to only a subset of columns.
#
# You can make as many models as you like.
#
# Good luck! 😀

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

# %%
pd.read_csv('./data/drug_reviews_cleaned.csv')
# Out:
#       User_ID                  drugName    condition  \
# 0      164952  Phentermine / topiramate  Weight Loss
# 1      145900                    Qsymia  Weight Loss
# 2       52117                  Adipex-P  Weight Loss
# 3      145785                    Qsymia  Weight Loss
# 4      145840                    Qsymia  Weight Loss
# ...       ...                       ...          ...
# 3604   145579                    Qsymia  Weight Loss
# 3605   128296               Phentermine  Weight Loss
# 3606   185393                   Saxenda  Weight Loss
# 3607    39213                  Contrave  Weight Loss
# 3608   128820               Phentermine  Weight Loss
#
#                                                  review  rating  \
# 0     "I have been on the Qysmia for 3 weeks now.  I...     8.0
# 1     "My Dr agreed to over see putting me on Qsymia...     9.0
# 2     "I just started Adipex-P 37.5mg on March 6th, ...     8.0
# 3     "Began taking Qsymia 3.75 in June 2013. Its on...    10.0
# ...
